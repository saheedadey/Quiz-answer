# %% [markdown]
# <a href="https://colab.research.google.com/github/saheedadey/Quiz-answer/blob/master/Hackathon1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Team Global Green
# ###> We are working on "Preventing The Amplification of Fake News on Climate Change"

# %% [markdown]
# The Datasets: We use two publicly available datasets,
# namely PolitiFact political claims, climate and health data generated from different websites (Popat et al, 2018)

# %%
import pandas as pd

# %%
#Lets dowload the dataset
url = 'https://github.com/rahulOmishra/SUMO/raw/main/climate_claims_raw.xlsx'
df = pd.read_excel(url)
df
# Out:
#      climate_claim  ... Unnamed: 4
# 0         Claim_id  ...      Label
# 1                0  ...      False
# 2                0  ...      False
# 3                0  ...      False
# 4                0  ...      False
# ...            ...  ...        ...
# 1032           105  ...      False
# 1033           105  ...      False
# 1034           105  ...      False
# 1035           105  ...      False
# 1036           105  ...      False
#
# [1037 rows x 5 columns]

# %%
df1 = pd.DataFrame(df)
df1
# Out:
#      climate_claim  ... Unnamed: 4
# 0         Claim_id  ...      Label
# 1                0  ...      False
# 2                0  ...      False
# 3                0  ...      False
# 4                0  ...      False
# ...            ...  ...        ...
# 1032           105  ...      False
# 1033           105  ...      False
# 1034           105  ...      False
# 1035           105  ...      False
# 1036           105  ...      False
#
# [1037 rows x 5 columns]

# %%
# Checking the Dataset column
df.head(1)
# Out:
#   climate_claim Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0      Claim_id      Claim      Title   Doc_text      Label

# %%
# Since many of the Column are Unnamed, we try to rename them appropriately

replace = {'climate_claim': 'ID', 'Unnamed: 1':"Claim", 'Unnamed: 2':'Title', 'Unnamed: 3':'Story', 'Unnamed: 4':'Label' }

# %%
df1.rename(columns=replace, inplace=True)
df
# Out:
#             ID  ...  Label
# 0     Claim_id  ...  Label
# 1            0  ...  False
# 2            0  ...  False
# 3            0  ...  False
# 4            0  ...  False
# ...        ...  ...    ...
# 1032       105  ...  False
# 1033       105  ...  False
# 1034       105  ...  False
# 1035       105  ...  False
# 1036       105  ...  False
#
# [1037 rows x 5 columns]

# %%
# Droping the fisrt row because it doesn't useful
df1.drop(index=df.index[0], axis = 0)
# Out:
#        ID  ...  Label
# 1       0  ...  False
# 2       0  ...  False
# 3       0  ...  False
# 4       0  ...  False
# 5       0  ...  False
# ...   ...  ...    ...
# 1032  105  ...  False
# 1033  105  ...  False
# 1034  105  ...  False
# 1035  105  ...  False
# 1036  105  ...  False
#
# [1036 rows x 5 columns]

# %%
df1.drop(['ID', 'Title', 'Story'], axis = 1, inplace=True)

# %%
df1
# Out:
#                                                   Claim  Label
# 0                                                 Claim  Label
# 1     The drop in NO2 content has only been ?slight?...  False
# 2     The drop in NO2 content has only been ?slight?...  False
# 3     The drop in NO2 content has only been ?slight?...  False
# 4     The drop in NO2 content has only been ?slight?...  False
# ...                                                 ...    ...
# 1032               Smoking may protect against COVID-19  False
# 1033               Smoking may protect against COVID-19  False
# 1034               Smoking may protect against COVID-19  False
# 1035               Smoking may protect against COVID-19  False
# 1036               Smoking may protect against COVID-19  False
#
# [1037 rows x 2 columns]

# %% [markdown]
# ### Let's try to Tokenize the dataset to be able to generate embedling
